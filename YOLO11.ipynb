# %% [markdown]
# <a href="https://colab.research.google.com/github/Thawin2551/raicamp2025/blob/main/YOLO11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup YOLO11
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 35.5/112.6 GB disk)

# %% [markdown]
# # 1. Predict ( Test Setup YOLO11)
#
# YOLOv8 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLO11 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %%
# Run inference on an image with YOLOv11n
# !yolo predict model=yolo11n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 149MB/s]
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# ...
# 100% 134k/134k [00:00<00:00, 9.04MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 84.3ms
# Speed: 20.5ms preprocess, 84.3ms inference, 484.2ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 2. Add Zip Data Export YOLO11 for Roboflow

# %%
import zipfile
from google.colab import files

# %cd /content
uploaded = files.upload()
for filename in uploaded.keys():
  pass

zip_ref = zipfile.ZipFile(filename, 'r')
zip_ref.extractall("/content/")
# Out:
# /content
#      <input type="file" id="files-029c852a-e453-4617-a92e-6c42b48f2cc4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-029c852a-e453-4617-a92e-6c42b48f2cc4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# # 3. Train Data Roboflow

# %%
# Validate YOLOv8n
# !yolo train model=yolo11n.pt data=data.yaml epochs=200 imgsz=640
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # 4. Test Model Training

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt conf=0.1 imgsz=640 source='/content/test/images/'
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/3 /content/test/images/yt-qCY8_SQ93O8-0003_jpg.rf.522ce39467d33842a44e27d71bf1d9d4.jpg: 640x640 2 1 coins, 12.9ms
# image 2/3 /content/test/images/yt-qCY8_SQ93O8-0009_jpg.rf.6aee2ec16bfa7385960aaf06bf098e3a.jpg: 640x640 2 1 coins, 2 10 coins, 2 5 coins, 9.8ms
# image 3/3 /content/test/images/yt-qCY8_SQ93O8-0012_jpg.rf.428076b5c15e230f15759b35790893a4.jpg: 640x640 2 1 coins, 2 10 coins, 2 5 coins, 9.1ms
# Speed: 2.4ms preprocess, 10.6ms inference, 54.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 5. Test Video for Model Ai

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt  conf=0.1 imgsz=640 source='/content/runs/detect/predict2/DataTestENV2.mp4'
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# video 1/1 (frame 1/2392) /content/runs/detect/predict2/DataTestENV2.mp4: 640x384 1 1 coin, 51.2ms
# video 1/1 (frame 2/2392) /content/runs/detect/predict2/DataTestENV2.mp4: 640x384 1 1 coin, 12.4ms
# video 1/1 (frame 3/2392) /content/runs/detect/predict2/DataTestENV2.mp4: 640x384 1 1 coin, 11.0ms
# video 1/1 (frame 4/2392) /content/runs/detect/predict2/DataTestENV2.mp4: 640x384 1 1 coin, 11.5ms
# video 1/1 (frame 5/2392) /content/runs/detect/predict2/DataTestENV2.mp4: 640x384 1 1 coin, 16.3ms
# video 1/1 (frame 6/2392) /content/runs/detect/predict2/DataTestENV2.mp4: 640x384 1 1 coin, 12.0ms
# video 1/1 (frame 7/2392) /content/runs/detect/predict2/DataTestENV2.mp4: 640x384 1 1 coin, 13.0ms
# video 1/1 (frame 8/2392) /content/runs/detect/predict2/DataTestENV2.mp4: 640x384 1 1 coin, 12.2ms
# ...
